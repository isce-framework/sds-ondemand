# %%
# %%bash
#
# pip install kernda
#
# %%bash
# mkdir -p ~/.local/envs
# conda config --append envs_dirs ~/.local/envs
#
# local_base="/home/jovyan/.local/envs"
# env_base=${local_base}/qed
# qed_tools_dir=${env_base}/tools
#
# date_str=`date +%Y%m%d-%H%M%S`
#
# sudo yum install -y git vim zip unzip openssh-server
#
# # (re)create the QED environment
# conda env create -f qed_support_files/qed_environment.yaml -p ${env_base} --force
#
# #this hideousness extracts the active major.minor (only) python version
# python_version=`conda run -p ${env_base} python --version | awk '/Python/ {print $2}' | awk 'BEGIN { FS="." } { print $1"."$2 }'`
#
# # install/build QED and dependencies
# mkdir -p ${qed_tools_dir}
# pushd ${qed_tools_dir}
# git clone https://github.com/aivazis/mm
# git clone https://github.com/pyre/pyre
# git clone https://github.com/aivazis/qed
# popd
#
# mkdir -p /home/jovyan/.pyre
# if [ -f /home/jovyan/.pyre/mm.pfg ]
# then
#      mv /home/jovyan/.pyre/mm.pfg /home/jovyan/.pyre/mm.pfg.${date_str}
# fi
# sed -e "s:@PREFIX@:${env_base}:g" qed_support_files/mm.pfg > /home/jovyan/.pyre/mm.pfg
#
# mkdir -p /home/jovyan/.mm
# if [ -f /home/jovyan/.mm/config.mm ]
# then
#      mv /home/jovyan/.mm/config.mm /home/jovyan/.mm/config.mm.${date_str}
# fi
# sed -e "s:@PYTHON_VERSION@:${python_version}:g" qed_support_files/config.mm > /home/jovyan/.mm/config.mm
# if [ ! -f /home/jovyan/.pyre/qed.yaml ]
# then
#     cp qed_support_files/qed.yaml /home/jovyan/.pyre/qed.yaml
# fi
#
# # build pyre
# pushd ${qed_tools_dir}/pyre
# conda run -n qed python ${qed_tools_dir}/mm/mm.py --serial
# popd
#
# # build qed
# pushd ${qed_tools_dir}/qed
# conda run -n qed python ${qed_tools_dir}/mm/mm.py --serial
# popd
#
# mkdir -p /home/jovyan/.jupyter
# if [ -f /home/jovyan/.jupyter/jupyter_notebook_config.py ]
# then
#     mv /home/jovyan/.jupyter/jupyter_notebook_config.py /home/jovyan/.jupyter/jupyter_notebook_config.py.${date_str}
# fi
# cp qed_support_files/jupyter_notebook_config.py.ops /home/jovyan/.jupyter/jupyter_notebook_config.py
#
# # update the ipykernel to recognize the new kernel
# conda run -n qed python -m ipykernel install --user --name qed --display-name "qed"
# # now invoke kernda to modify the kernel file to ensure the kernel is invoked from within the conda environment
# conda run -n qed kernda --env-dir ${env_base} --display-name qed -o ~/.local/share/jupyter/kernels/qed/kernel.json
#
# source /opt/conda/bin/activate ${env_base}
# sudo yum install -y httpd
# pip install -U flask
# # pip install -U jupyter-server-proxy
# # jupyter serverextension enable --py jupyter_server_proxy --sys-prefix
# # jupyter labextension install @jupyterlab/server-proxy
# Out:
# Loaded plugins: fastestmirror, ovl
# Determining fastest mirrors
#  * base: download.cf.centos.org
#  * centos-sclo-rh: download.cf.centos.org
#  * extras: download.cf.centos.org
#  * updates: download.cf.centos.org
# Package zip-3.0-11.el7.x86_64 already installed and latest version
# Resolving Dependencies
# --> Running transaction check
# ---> Package git.x86_64 0:1.8.3.1-23.el7_8 will be installed
# --> Processing Dependency: perl-Git = 1.8.3.1-23.el7_8 for package: git-1.8.3.1-23.el7_8.x86_64
# --> Processing Dependency: rsync for package: git-1.8.3.1-23.el7_8.x86_64
# --> Processing Dependency: perl(Term::ReadKey) for package: git-1.8.3.1-23.el7_8.x86_64
# --> Processing Dependency: perl(Git) for package: git-1.8.3.1-23.el7_8.x86_64
# --> Processing Dependency: perl(Error) for package: git-1.8.3.1-23.el7_8.x86_64
# ---> Package openssh-server.x86_64 0:7.4p1-22.el7_9 will be installed
# --> Processing Dependency: libwrap.so.0()(64bit) for package: openssh-server-7.4p1-22.el7_9.x86_64
# ---> Package unzip.x86_64 0:6.0-24.el7_9 will be installed
# ---> Package vim-enhanced.x86_64 2:7.4.629-8.el7_9 will be installed
# --> Processing Dependency: vim-common = 2:7.4.629-8.el7_9 for package: 2:vim-enhanced-7.4.629-8.el7_9.x86_64
# --> Processing Dependency: libgpm.so.2()(64bit) for package: 2:vim-enhanced-7.4.629-8.el7_9.x86_64
# --> Running transaction check
# ---> Package gpm-libs.x86_64 0:1.20.7-6.el7 will be installed
# ---> Package perl-Error.noarch 1:0.17020-2.el7 will be installed
# ---> Package perl-Git.noarch 0:1.8.3.1-23.el7_8 will be installed
# ---> Package perl-TermReadKey.x86_64 0:2.30-20.el7 will be installed
# ---> Package rsync.x86_64 0:3.1.2-10.el7 will be installed
# ---> Package tcp_wrappers-libs.x86_64 0:7.6-77.el7 will be installed
# ---> Package vim-common.x86_64 2:7.4.629-8.el7_9 will be installed
# --> Processing Dependency: vim-filesystem for package: 2:vim-common-7.4.629-8.el7_9.x86_64
# --> Running transaction check
# ---> Package vim-filesystem.x86_64 2:7.4.629-8.el7_9 will be installed
# --> Finished Dependency Resolution
#
# Dependencies Resolved
#
# ================================================================================
#  Package                Arch        Version                  Repository    Size
# ================================================================================
# Installing:
#  git                    x86_64      1.8.3.1-23.el7_8         base         4.4 M
#  openssh-server         x86_64      7.4p1-22.el7_9           updates      459 k
#  unzip                  x86_64      6.0-24.el7_9             updates      172 k
#  vim-enhanced           x86_64      2:7.4.629-8.el7_9        updates      1.1 M
# Installing for dependencies:
#  gpm-libs               x86_64      1.20.7-6.el7             base          32 k
#  perl-Error             noarch      1:0.17020-2.el7          base          32 k
#  perl-Git               noarch      1.8.3.1-23.el7_8         base          56 k
#  perl-TermReadKey       x86_64      2.30-20.el7              base          31 k
#  rsync                  x86_64      3.1.2-10.el7             base         404 k
#  tcp_wrappers-libs      x86_64      7.6-77.el7               base          66 k
#  vim-common             x86_64      2:7.4.629-8.el7_9        updates      5.9 M
#  vim-filesystem         x86_64      2:7.4.629-8.el7_9        updates       11 k
#
# Transaction Summary
# ================================================================================
# Install  4 Packages (+8 Dependent packages)
#
# Total download size: 13 M
# Installed size: 48 M
# Downloading packages:
# --------------------------------------------------------------------------------
# Total                                               26 MB/s |  13 MB  00:00
# Running transaction check
# Running transaction test
# Transaction test succeeded
# Running transaction
#   Installing : 1:perl-Error-0.17020-2.el7.noarch                           1/12
#   Installing : 2:vim-filesystem-7.4.629-8.el7_9.x86_64                     2/12
#   Installing : 2:vim-common-7.4.629-8.el7_9.x86_64                         3/12
#   Installing : tcp_wrappers-libs-7.6-77.el7.x86_64                         4/12
#   Installing : rsync-3.1.2-10.el7.x86_64                                   5/12
#   Installing : gpm-libs-1.20.7-6.el7.x86_64                                6/12
#   Installing : perl-TermReadKey-2.30-20.el7.x86_64                         7/12
#   Installing : perl-Git-1.8.3.1-23.el7_8.noarch                            8/12
#   Installing : git-1.8.3.1-23.el7_8.x86_64                                 9/12
#   Installing : 2:vim-enhanced-7.4.629-8.el7_9.x86_64                      10/12
#   Installing : openssh-server-7.4p1-22.el7_9.x86_64                       11/12
#   Installing : unzip-6.0-24.el7_9.x86_64                                  12/12
#   Verifying  : git-1.8.3.1-23.el7_8.x86_64                                 1/12
#   Verifying  : perl-TermReadKey-2.30-20.el7.x86_64                         2/12
#   Verifying  : openssh-server-7.4p1-22.el7_9.x86_64                        3/12
#   Verifying  : 1:perl-Error-0.17020-2.el7.noarch                           4/12
#   Verifying  : gpm-libs-1.20.7-6.el7.x86_64                                5/12
#   Verifying  : 2:vim-common-7.4.629-8.el7_9.x86_64                         6/12
#   Verifying  : rsync-3.1.2-10.el7.x86_64                                   7/12
#   Verifying  : tcp_wrappers-libs-7.6-77.el7.x86_64                         8/12
#   Verifying  : 2:vim-enhanced-7.4.629-8.el7_9.x86_64                       9/12
#   Verifying  : unzip-6.0-24.el7_9.x86_64                                  10/12
#   Verifying  : 2:vim-filesystem-7.4.629-8.el7_9.x86_64                    11/12
#   Verifying  : perl-Git-1.8.3.1-23.el7_8.noarch                           12/12
#
# Installed:
#   git.x86_64 0:1.8.3.1-23.el7_8      openssh-server.x86_64 0:7.4p1-22.el7_9
#   unzip.x86_64 0:6.0-24.el7_9        vim-enhanced.x86_64 2:7.4.629-8.el7_9
#
# Dependency Installed:
#   gpm-libs.x86_64 0:1.20.7-6.el7       perl-Error.noarch 1:0.17020-2.el7
#   perl-Git.noarch 0:1.8.3.1-23.el7_8   perl-TermReadKey.x86_64 0:2.30-20.el7
#   rsync.x86_64 0:3.1.2-10.el7          tcp_wrappers-libs.x86_64 0:7.6-77.el7
#   vim-common.x86_64 2:7.4.629-8.el7_9  vim-filesystem.x86_64 2:7.4.629-8.el7_9
#
# Complete!
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base conda
# Downloading and Extracting Packages
# jupyter_client-7.2.2 | 90 KB     | ########## | 100%
# pycparser-2.21       | 100 KB    | ########## | 100%
# importlib_resources- | 22 KB     | ########## | 100%
# nbformat-5.3.0       | 104 KB    | ########## | 100%
# python-fastjsonschem | 243 KB    | ########## | 100%
# ipython_genutils-0.2 | 21 KB     | ########## | 100%
# wheel-0.37.1         | 31 KB     | ########## | 100%
# cryptography-36.0.2  | 1.6 MB    | ########## | 100%
# anyio-3.5.0          | 152 KB    | ########## | 100%
# tornado-6.1          | 649 KB    | ########## | 100%
# libstdcxx-ng-11.2.0  | 4.2 MB    | ########## | 100%
# terminado-0.13.3     | 27 KB     | ########## | 100%
# libgomp-11.2.0       | 432 KB    | ########## | 100%
# tinycss2-1.1.1       | 23 KB     | ########## | 100%
# prompt-toolkit-3.0.2 | 252 KB    | ########## | 100%
# gsl-2.7              | 3.2 MB    | ########## | 100%
# sqlite-3.38.2        | 1.5 MB    | ########## | 100%
# libgfortran5-11.2.0  | 1.7 MB    | ########## | 100%
# pytz-2022.1          | 242 KB    | ########## | 100%
# pyrsistent-0.18.1    | 92 KB     | ########## | 100%
# libuv-1.43.0         | 1.0 MB    | ########## | 100%
# requests-2.27.1      | 53 KB     | ########## | 100%
# nbconvert-pandoc-6.5 | 4 KB      | ########## | 100%
# websocket-client-1.3 | 41 KB     | ########## | 100%
# libedit-3.1.20191231 | 121 KB    | ########## | 100%
# zlib-1.2.11          | 88 KB     | ########## | 100%
# sniffio-1.2.0        | 15 KB     | ########## | 100%
# notebook-shim-0.1.0  | 15 KB     | ########## | 100%
# pexpect-4.8.0        | 47 KB     | ########## | 100%
# nbclassic-0.3.7      | 14 KB     | ########## | 100%
# backports-1.0        | 4 KB      | ########## | 100%
# gxx-11.2.0           | 24 KB     | ########## | 100%
# libssh2-1.10.0       | 233 KB    | ########## | 100%
# pysocks-1.7.1        | 28 KB     | ########## | 100%
# kernel-headers_linux | 707 KB    | ########## | 100%
# bzip2-1.0.8          | 484 KB    | ########## | 100%
# attrs-21.4.0         | 49 KB     | ########## | 100%
# libxml2-2.9.13       | 773 KB    | ########## | 100%
# executing-0.8.3      | 18 KB     | ########## | 100%
# nest-asyncio-1.5.5   | 9 KB      | ########## | 100%
# pcre2-10.37          | 1.1 MB    | ########## | 100%
# expat-2.4.8          | 187 KB    | ########## | 100%
# importlib-metadata-4 | 33 KB     | ########## | 100%
# wcwidth-0.2.5        | 33 KB     | ########## | 100%
# pickleshare-0.7.5    | 9 KB      | ########## | 100%
# jupyter_server-1.16. | 242 KB    | ########## | 100%
# tzdata-2022a         | 121 KB    | ########## | 100%
# nodejs-17.9.0        | 15.1 MB   | ########## | 100%
# send2trash-1.8.0     | 17 KB     | ########## | 100%
# pybind11-global-2.9. | 192 KB    | ########## | 100%
# tk-8.6.12            | 3.3 MB    | ########## | 100%
# python-dateutil-2.8. | 240 KB    | ########## | 100%
# libcblas-3.9.0       | 12 KB     | ########## | 100%
# libopenblas-0.3.20   | 10.1 MB   | ########## | 100%
# pyzmq-22.3.0         | 516 KB    | ########## | 100%
# libsanitizer-11.2.0  | 5.9 MB    | ########## | 100%
# libnsl-2.0.0         | 31 KB     | ########## | 100%
# readline-8.1         | 295 KB    | ########## | 100%
# ipython-8.2.0        | 1.1 MB    | ########## | 100%
# nbconvert-core-6.5.0 | 425 KB    | ########## | 100%
# jedi-0.18.1          | 999 KB    | ########## | 100%
# tqdm-4.64.0          | 81 KB     | ########## | 100%
# fftw-3.3.10          | 6.4 MB    | ########## | 100%
# hdf5-1.12.1          | 3.5 MB    | ########## | 100%
# prometheus_client-0. | 49 KB     | ########## | 100%
# pygments-2.11.2      | 796 KB    | ########## | 100%
# numpy-1.22.3         | 6.8 MB    | ########## | 100%
# brotlipy-0.7.0       | 342 KB    | ########## | 100%
# libzlib-1.2.11       | 60 KB     | ########## | 100%
# pyyaml-6.0           | 178 KB    | ########## | 100%
# nbclient-0.6.0       | 64 KB     | ########## | 100%
# matplotlib-inline-0. | 11 KB     | ########## | 100%
# urllib3-1.26.9       | 100 KB    | ########## | 100%
# pybind11-2.9.2       | 162 KB    | ########## | 100%
# libffi-3.3           | 51 KB     | ########## | 100%
# icu-70.1             | 13.5 MB   | ########## | 100%
# zstd-1.5.2           | 458 KB    | ########## | 100%
# json5-0.9.5          | 20 KB     | ########## | 100%
# gettext-0.19.8.1     | 3.6 MB    | ########## | 100%
# pure_eval-0.2.2      | 14 KB     | ########## | 100%
# jupyterlab_server-2. | 49 KB     | ########## | 100%
# pandoc-2.18          | 12.5 MB   | ########## | 100%
# gfortran_impl_linux- | 15.1 MB   | ########## | 100%
# krb5-1.19.3          | 1.4 MB    | ########## | 100%
# sysroot_linux-64-2.1 | 31.4 MB   | ########## | 100%
# webencodings-0.5.1   | 12 KB     | ########## | 100%
# xz-5.2.5             | 343 KB    | ########## | 100%
# jinja2-3.1.1         | 99 KB     | ########## | 100%
# argon2-cffi-21.3.0   | 15 KB     | ########## | 100%
# parso-0.8.3          | 69 KB     | ########## | 100%
# libstdcxx-devel_linu | 9.7 MB    | ########## | 100%
# jupyterlab_pygments- | 30 KB     | ########## | 100%
# idna-3.3             | 55 KB     | ########## | 100%
# traitlets-5.1.1      | 82 KB     | ########## | 100%
# pandocfilters-1.5.0  | 11 KB     | ########## | 100%
# mistune-0.8.4        | 54 KB     | ########## | 100%
# markupsafe-2.1.1     | 22 KB     | ########## | 100%
# jupyterlab-3.2.9     | 3.6 MB    | ########## | 100%
# decorator-5.1.1      | 12 KB     | ########## | 100%
# pip-22.0.4           | 1.5 MB    | ########## | 100%
# zeromq-4.3.4         | 351 KB    | ########## | 100%
# argon2-cffi-bindings | 34 KB     | ########## | 100%
# c-ares-1.18.1        | 113 KB    | ########## | 100%
# gcc_impl_linux-64-11 | 49.7 MB   | ########## | 100%
# gcc-11.2.0           | 24 KB     | ########## | 100%
# stack_data-0.2.0     | 21 KB     | ########## | 100%
# defusedxml-0.7.1     | 23 KB     | ########## | 100%
# pycosat-0.6.3        | 108 KB    | ########## | 100%
# curl-7.82.0          | 90 KB     | ########## | 100%
# charset-normalizer-2 | 35 KB     | ########## | 100%
# perl-5.32.1          | 14.4 MB   | ########## | 100%
# python-3.9.7         | 18.6 MB   | ########## | 100%
# libsodium-1.0.18     | 366 KB    | ########## | 100%
# backcall-0.2.0       | 13 KB     | ########## | 100%
# make-4.3             | 507 KB    | ########## | 100%
# conda-package-handli | 1.0 MB    | ########## | 100%
# libgfortran-ng-11.2. | 23 KB     | ########## | 100%
# pyparsing-3.0.8      | 79 KB     | ########## | 100%
# debugpy-1.6.0        | 2.0 MB    | ########## | 100%
# libev-4.33           | 104 KB    | ########## | 100%
# libnghttp2-1.47.0    | 808 KB    | ########## | 100%
# keyutils-1.6.1       | 115 KB    | ########## | 100%
# flit-core-3.7.1      | 44 KB     | ########## | 100%
# babel-2.9.1          | 6.2 MB    | ########## | 100%
# ld_impl_linux-64-2.3 | 667 KB    | ########## | 100%
# libsolv-0.7.19       | 445 KB    | ########## | 100%
# psutil-5.9.0         | 344 KB    | ########## | 100%
# yaml-0.2.5           | 87 KB     | ########## | 100%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
# ncurses-6.3          | 1002 KB   | ########## | 100%
# asttokens-2.0.5      | 21 KB     | ########## | 100%
# jupyter_core-4.9.2   | 81 KB     | ########## | 100%
# soupsieve-2.3.1      | 33 KB     | ########## | 100%
# gfortran-11.2.0      | 24 KB     | ########## | 100%
# binutils_impl_linux- | 10.4 MB   | ########## | 100%
# gxx_impl_linux-64-11 | 12.3 MB   | ########## | 100%
# ipykernel-6.13.0     | 185 KB    | ########## | 100%
# libgcc-ng-11.2.0     | 911 KB    | ########## | 100%
# libgcc-devel_linux-6 | 3.3 MB    | ########## | 100%
# beautifulsoup4-4.11. | 96 KB     | ########## | 100%
# zipp-3.8.0           | 12 KB     | ########## | 100%
# jsonschema-4.4.0     | 57 KB     | ########## | 100%
# ptyprocess-0.7.0     | 16 KB     | ########## | 100%
# six-1.16.0           | 14 KB     | ########## | 100%
# setuptools-62.1.0    | 1.3 MB    | ########## | 100%
# libcurl-7.82.0       | 341 KB    | ########## | 100%
# python_abi-3.9       | 4 KB      | ########## | 100%
# backports.functools_ | 9 KB      | ########## | 100%
# packaging-21.3       | 36 KB     | ########## | 100%
# ruamel_yaml-0.15.80  | 268 KB    | ########## | 100%
# entrypoints-0.4      | 9 KB      | ########## | 100%
# liblapack-3.9.0      | 12 KB     | ########## | 100%
# pyopenssl-22.0.0     | 49 KB     | ########## | 100%
# libblas-3.9.0        | 12 KB     | ########## | 100%
# bleach-5.0.0         | 123 KB    | ########## | 100%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
# nbconvert-6.5.0      | 6 KB      | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working... Ran pip subprocess with arguments:
# ['/home/jovyan/.local/envs/qed/bin/python', '-m', 'pip', 'install', '-U', '-r', '/home/jovyan/scratch_workspace/qed_support_files/condaenv.7qoql1kx.requirements.txt']
# Pip subprocess output:
# Collecting aniso8601==9.0.1
#   Using cached aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
# Collecting graphene==3.0
#   Using cached graphene-3.0-py2.py3-none-any.whl (112 kB)
# Collecting graphql-core==3.1.7
#   Using cached graphql_core-3.1.7-py3-none-any.whl (189 kB)
# Collecting graphql-relay==3.1.5
#   Using cached graphql_relay-3.1.5-py3-none-any.whl (17 kB)
# Collecting scons==4.3.0
#   Using cached SCons-4.3.0-py3-none-any.whl (4.2 MB)
# Requirement already satisfied: setuptools in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from scons==4.3.0->-r /home/jovyan/scratch_workspace/qed_support_files/condaenv.7qoql1kx.requirements.txt (line 5)) (62.1.0)
# Installing collected packages: aniso8601, scons, graphql-core, graphql-relay, graphene
# Successfully installed aniso8601-9.0.1 graphene-3.0 graphql-core-3.1.7 graphql-relay-3.1.5 scons-4.3.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate /home/jovyan/.local/envs/qed
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# ~/.local/envs/qed/tools ~/scratch_workspace
# Cloning into 'mm'...
# Cloning into 'pyre'...
# Cloning into 'qed'...
# ~/scratch_workspace
# ~/.local/envs/qed/tools/pyre ~/scratch_workspace
#   [mkdir] /tmp/builds/opt-shared-linux-x86_64/journal/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/journal/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/journal/ext/
#   [python] packages/journal/Alert.py
#   [python] packages/journal/ANSI.py
#   [python] packages/journal/ANSI_x11.py
#   [python] packages/journal/ASCII.py
#   [python] packages/journal/Bland.py
#   [python] packages/journal/Channel.py
#   [python] packages/journal/Chronicler.py
#   [python] packages/journal/Console.py
#   [python] packages/journal/CSI.py
#   [python] packages/journal/Debug.py
#   [python] packages/journal/Device.py
#   [python] packages/journal/Entry.py
#   [python] packages/journal/ErrorConsole.py
#   [python] packages/journal/Error.py
#   [python] packages/journal/exceptions.py
#   [python] packages/journal/File.py
#   [python] packages/journal/Firewall.py
#   [python] packages/journal/Help.py
#   [python] packages/journal/Index.py
#   [python] packages/journal/Informational.py
#   [python] packages/journal/__init__.py
#   [python] packages/journal/Inventory.py
#   [python] packages/journal/Memo.py
#   [python] packages/journal/Null.py
#   [python] packages/journal/palettes.py
#   [python] packages/journal/Renderer.py
#   [python] packages/journal/Stream.py
#   [python] packages/journal/Trash.py
#   [python] packages/journal/Warning.py
#   [python] packages/journal/ext/__init__.py
#   [sed] packages/journal/meta.py.in
#   [python] packages/journal/meta.py.in
#   [pkg] journal.pkg
#   [mkdir] /home/jovyan/.local/envs/qed/include/pyre/journal/
#   [mkdir] /tmp/builds/opt-shared-linux-x86_64/journal/libjournal/
#   [cp] lib/journal/journal.h
#   [cp] lib/journal/Alert.h
#   [cp] lib/journal/ANSI.h
#   [cp] lib/journal/api.h
#   [cp] lib/journal/ASCII.h
#   [cp] lib/journal/Bland.h
#   [cp] lib/journal/Channel.h
#   [cp] lib/journal/Chronicler.h
#   [cp] lib/journal/Code.h
#   [cp] lib/journal/Color.h
#   [cp] lib/journal/Console.h
#   [cp] lib/journal/CSI.h
#   [cp] lib/journal/Debug.h
#   [cp] lib/journal/debuginfo.h
#   [cp] lib/journal/Dent.h
#   [cp] lib/journal/Detail.h
#   [cp] lib/journal/Device.h
#   [cp] lib/journal/Entry.h
#   [cp] lib/journal/ErrorConsole.h
#   [cp] lib/journal/Error.h
#   [cp] lib/journal/exceptions.h
#   [cp] lib/journal/externals.h
#   [cp] lib/journal/File.h
#   [cp] lib/journal/Firewall.h
#   [cp] lib/journal/firewalls.h
#   [cp] lib/journal/Flush.h
#   [cp] lib/journal/forward.h
#   [cp] lib/journal/Help.h
#   [cp] lib/journal/Index.h
#   [cp] lib/journal/Informational.h
#   [cp] lib/journal/Inventory.h
#   [cp] lib/journal/InventoryProxy.h
#   [cp] lib/journal/Locator.h
#   [cp] lib/journal/macros.h
#   [cp] lib/journal/manipulators.h
#   [cp] lib/journal/Memo.h
#   [cp] lib/journal/Note.h
#   [cp] lib/journal/Null.h
#   [cp] lib/journal/public.h
#   [cp] lib/journal/Renderer.h
#   [cp] lib/journal/Stream.h
#   [cp] lib/journal/Trash.h
#   [cp] lib/journal/Warning.h
#   [cp] lib/journal/Channel.icc
#   [cp] lib/journal/Chronicler.icc
#   [cp] lib/journal/Code.icc
#   [cp] lib/journal/Color.icc
#   [cp] lib/journal/Console.icc
#   [cp] lib/journal/CSI.icc
#   [cp] lib/journal/Debug.icc
#   [cp] lib/journal/Dent.icc
#   [cp] lib/journal/Detail.icc
#   [cp] lib/journal/Device.icc
#   [cp] lib/journal/Entry.icc
#   [cp] lib/journal/ErrorConsole.icc
#   [cp] lib/journal/Error.icc
#   [cp] lib/journal/exceptions.icc
#   [cp] lib/journal/File.icc
#   [cp] lib/journal/Firewall.icc
#   [cp] lib/journal/Flush.icc
#   [cp] lib/journal/Help.icc
#   [cp] lib/journal/Index.icc
#   [cp] lib/journal/Informational.icc
#   [cp] lib/journal/Inventory.icc
#   [cp] lib/journal/InventoryProxy.icc
#   [cp] lib/journal/Locator.icc
#   [cp] lib/journal/Note.icc
#   [cp] lib/journal/Null.icc
#   [cp] lib/journal/Stream.icc
#   [cp] lib/journal/Trash.icc
#   [cp] lib/journal/Warning.icc
#   [c++] lib/journal/Alert.cc
#   [c++] lib/journal/ANSI.cc
#   [c++] lib/journal/ANSI_x11.cc
#   [c++] lib/journal/Bland.cc
#   [c++] lib/journal/Chronicler.cc
#   [c++] lib/journal/Console.cc
#   [c++] lib/journal/debuginfo.cc
#   [c++] lib/journal/Device.cc
#   [c++] lib/journal/ErrorConsole.cc
#   [c++] lib/journal/File.cc
#   [c++] lib/journal/firewalls.cc
#   [c++] lib/journal/Memo.cc
#   [c++] lib/journal/Renderer.cc
#   [c++] lib/journal/Stream.cc
#   [c++] lib/journal/Trash.cc
#   [ar] libjournal.a
#   [dll] libjournal.so
#   [lib] journal.lib
#   [mkdir] /tmp/builds/opt-shared-linux-x86_64/journal/extjournal/
#   [mkdir] /tmp/builds/opt-shared-linux-x86_64/journal/libjournalmodule/
#   [c++] extensions/journal/api.cc
#   [c++] extensions/journal/chronicler.cc
#   [c++] extensions/journal/debug.cc
#   [c++] extensions/journal/devices.cc
#   [c++] extensions/journal/error.cc
#   [c++] extensions/journal/exceptions.cc
#   [c++] extensions/journal/firewall.cc
#   [c++] extensions/journal/help.cc
#   [c++] extensions/journal/info.cc
#   [c++] extensions/journal/opaque.cc
#   [c++] extensions/journal/warning.cc
#   [ar] libjournalmodule.a
#   [lib] journal.ext.lib
#   [module] extensions/journal/journal.cc
#   [ext] journal.ext
#   [project] journal
#   [mkdir] /tmp/builds/opt-shared-linux-x86_64/merlin/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/merlin/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/merlin/components/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/merlin/shells/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/merlin/assets/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/merlin/languages/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/merlin/protocols/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/merlin/schema/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/merlin/factories/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/merlin/scs/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/merlin/spells/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/merlin/compilers/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/merlin/compilers/python/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/merlin/compilers/gnu/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/merlin/compilers/llvm/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/merlin/cli/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/merlin/builders/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/merlin/builders/flow/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/merlin/builders/make/
#   [mkdir] /home/jovyan/.local/envs/qed/share/merlin/
#   [python] packages/merlin/exceptions.py
#   [python] packages/merlin/__init__.py
#   [python] packages/merlin/components/Curator.py
#   [python] packages/merlin/components/FHS.py
#   [python] packages/merlin/components/__init__.py
#   [python] packages/merlin/components/Language.py
#   [python] packages/merlin/components/Merlin.py
#   [python] packages/merlin/components/PythonClassifier.py
#   [python] packages/merlin/shells/Action.py
#   [python] packages/merlin/shells/Command.py
#   [python] packages/merlin/shells/__init__.py
#   [python] packages/merlin/shells/Merlin.py
#   [python] packages/merlin/assets/Asset.py
#   [python] packages/merlin/assets/Auxiliary.py
#   [python] packages/merlin/assets/Category.py
#   [python] packages/merlin/assets/Directory.py
#   [python] packages/merlin/assets/File.py
#   [python] packages/merlin/assets/Header.py
#   [python] packages/merlin/assets/__init__.py
#   [python] packages/merlin/assets/Library.py
#   [python] packages/merlin/assets/Product.py
#   [python] packages/merlin/assets/Project.py
#   [python] packages/merlin/assets/RealAsset.py
#   [python] packages/merlin/assets/Source.py
#   [python] packages/merlin/assets/Template.py
#   [python] packages/merlin/assets/Unrecognizable.py
#   [python] packages/merlin/languages/Autogen.py
#   [python] packages/merlin/languages/C.py
#   [python] packages/merlin/languages/CUDA.py
#   [python] packages/merlin/languages/CXX.py
#   [python] packages/merlin/languages/Cython.py
#   [python] packages/merlin/languages/FORTRAN.py
#   [python] packages/merlin/languages/__init__.py
#   [python] packages/merlin/languages/Language.py
#   [python] packages/merlin/languages/Python.py
#   [python] packages/merlin/protocols/AssetCategory.py
#   [python] packages/merlin/protocols/Asset.py
#   [python] packages/merlin/protocols/Builder.py
#   [python] packages/merlin/protocols/Compiler.py
#   [python] packages/merlin/protocols/Directory.py
#   [python] packages/merlin/protocols/File.py
#   [python] packages/merlin/protocols/__init__.py
#   [python] packages/merlin/protocols/Language.py
#   [python] packages/merlin/protocols/LibFlow.py
#   [python] packages/merlin/protocols/Library.py
#   [python] packages/merlin/protocols/PrefixLayout.py
#   [python] packages/merlin/protocols/Producer.py
#   [python] packages/merlin/protocols/Project.py
#   [python] packages/merlin/protocols/SCS.py
#   [python] packages/merlin/protocols/Specification.py
#   [python] packages/merlin/schema/__init__.py
#   [python] packages/merlin/schema/Project.py
#   [python] packages/merlin/factories/Copy.py
#   [python] packages/merlin/factories/Factory.py
#   [python] packages/merlin/factories/__init__.py
#   [python] packages/merlin/factories/Mkdir.py
#   [python] packages/merlin/scs/Git.py
#   [python] packages/merlin/scs/__init__.py
#   [python] packages/merlin/spells/About.py
#   [python] packages/merlin/spells/AssetManager.py
#   [python] packages/merlin/spells/Initializer.py
#   [python] packages/merlin/spells/__init__.py
#   [python] packages/merlin/compilers/__init__.py
#   [python] packages/merlin/compilers/python/__init__.py
#   [python] packages/merlin/compilers/gnu/GCC.py
#   [python] packages/merlin/compilers/gnu/GFortran.py
#   [python] packages/merlin/compilers/gnu/GNU.py
#   [python] packages/merlin/compilers/gnu/GXX.py
#   [python] packages/merlin/compilers/gnu/__init__.py
#   [python] packages/merlin/compilers/gnu/Suite.py
#   [python] packages/merlin/compilers/llvm/__init__.py
#   [python] packages/merlin/cli/About.py
#   [python] packages/merlin/cli/Complete.py
#   [python] packages/merlin/cli/Config.py
#   [python] packages/merlin/cli/Debug.py
#   [python] packages/merlin/cli/Help.py
#   [python] packages/merlin/cli/Info.py
#   [python] packages/merlin/cli/__init__.py
#   [python] packages/merlin/cli/Libraries.py
#   [python] packages/merlin/builders/Builder.py
#   [python] packages/merlin/builders/__init__.py
#   [python] packages/merlin/builders/flow/Builder.py
#   [python] packages/merlin/builders/flow/__init__.py
#   [python] packages/merlin/builders/flow/LibFlow.py
#   [python] packages/merlin/builders/make/Builder.py
#   [python] packages/merlin/builders/make/__init__.py
#   [python] packages/merlin/builders/make/LibFlow.py
#   [sed] packages/merlin/meta.py.in
#   [python] packages/merlin/meta.py.in
#   [cp] /bin/merlin
#   [cp] defaults/merlin/merlin.pfg
#   [pkg] merlin.pkg
#   [project] merlin
#   [mkdir] /tmp/builds/opt-shared-linux-x86_64/pyre-cuda/
#   [project] pyre-cuda
#   [mkdir] /tmp/builds/opt-shared-linux-x86_64/pyre-gsl/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/gsl/
#   [python] packages/gsl/blas.py
#   [python] packages/gsl/exceptions.py
#   [python] packages/gsl/Histogram.py
#   [python] packages/gsl/__init__.py
#   [python] packages/gsl/linalg.py
#   [python] packages/gsl/Matrix.py
#   [python] packages/gsl/MatrixView.py
#   [python] packages/gsl/pdf.py
#   [python] packages/gsl/Permutation.py
#   [python] packages/gsl/RNG.py
#   [python] packages/gsl/stats.py
#   [python] packages/gsl/Vector.py
#   [python] packages/gsl/VectorView.py
#   [pkg] pyre-gsl.pkg
#   [mkdir] /tmp/builds/opt-shared-linux-x86_64/pyre-gsl/extgsl/
#   [mkdir] /home/jovyan/.local/envs/qed/include/pyre/algebra/
#   [mkdir] /home/jovyan/.local/envs/qed/include/pyre/geometry/
#   [mkdir] /home/jovyan/.local/envs/qed/include/pyre/grid/
#   [mkdir] /home/jovyan/.local/envs/qed/include/pyre/h5/
#   [mkdir] /home/jovyan/.local/envs/qed/include/pyre/memory/
#   [mkdir] /home/jovyan/.local/envs/qed/include/pyre/patterns/
#   [mkdir] /home/jovyan/.local/envs/qed/include/pyre/timers/
#   [mkdir] /home/jovyan/.local/envs/qed/include/pyre/viz/
#   [mkdir] /home/jovyan/.local/envs/qed/include/pyre/viz/codecs/
#   [mkdir] /home/jovyan/.local/envs/qed/include/pyre/viz/colormaps/
#   [mkdir] /home/jovyan/.local/envs/qed/include/pyre/viz/colorspaces/
#   [mkdir] /home/jovyan/.local/envs/qed/include/pyre/viz/filters/
#   [mkdir] /tmp/builds/opt-shared-linux-x86_64/pyre/libpyre/
#   [cp] lib/pyre/geometry.h
#   [cp] lib/pyre/grid.h
#   [cp] lib/pyre/h5.h
#   [cp] lib/pyre/memory.h
#   [cp] lib/pyre/pyre.h
#   [cp] lib/pyre/timers.h
#   [cp] lib/pyre/viz.h
#   [cp] lib/pyre/viz/api.h
#   [cp] lib/pyre/viz/external.h
#   [cp] lib/pyre/viz/forward.h
#   [cp] lib/pyre/viz/public.h
#   [cp] lib/pyre/viz/codecs/BMP.h
#   [cp] lib/pyre/viz/codecs/BMP.icc
#   [cp] lib/pyre/viz/colormaps/Complex.h
#   [cp] lib/pyre/viz/colormaps/Gray.h
#   [cp] lib/pyre/viz/colormaps/HL.h
#   [cp] lib/pyre/viz/colormaps/HSB.h
#   [cp] lib/pyre/viz/colormaps/HSL.h
#   [cp] lib/pyre/viz/colormaps/RGB.h
#   [cp] lib/pyre/viz/colormaps/Complex.icc
#   [cp] lib/pyre/viz/colormaps/Gray.icc
#   [cp] lib/pyre/viz/colormaps/HL.icc
#   [cp] lib/pyre/viz/colormaps/HSB.icc
#   [cp] lib/pyre/viz/colormaps/HSL.icc
#   [cp] lib/pyre/viz/colormaps/RGB.icc
#   [cp] lib/pyre/viz/filters/Add.h
#   [cp] lib/pyre/viz/filters/Affine.h
#   [cp] lib/pyre/viz/filters/Amplitude.h
#   [cp] lib/pyre/viz/filters/Constant.h
#   [cp] lib/pyre/viz/filters/Cycle.h
#   [cp] lib/pyre/viz/filters/Decimate.h
#   [cp] lib/pyre/viz/filters/Geometric.h
#   [cp] lib/pyre/viz/filters/Imaginary.h
#   [cp] lib/pyre/viz/filters/LogSaw.h
#   [cp] lib/pyre/viz/filters/Multiply.h
#   [cp] lib/pyre/viz/filters/Parametric.h
#   [cp] lib/pyre/viz/filters/Phase.h
#   [cp] lib/pyre/viz/filters/PolarSaw.h
#   [cp] lib/pyre/viz/filters/Power.h
#   [cp] lib/pyre/viz/filters/Real.h
#   [cp] lib/pyre/viz/filters/Uniform.h
#   [cp] lib/pyre/viz/filters/Add.icc
#   [cp] lib/pyre/viz/filters/Affine.icc
#   [cp] lib/pyre/viz/filters/Amplitude.icc
#   [cp] lib/pyre/viz/filters/Constant.icc
#   [cp] lib/pyre/viz/filters/Cycle.icc
#   [cp] lib/pyre/viz/filters/Decimate.icc
#   [cp] lib/pyre/viz/filters/Geometric.icc
#   [cp] lib/pyre/viz/filters/Imaginary.icc
#   [cp] lib/pyre/viz/filters/LogSaw.icc
#   [cp] lib/pyre/viz/filters/Multiply.icc
#   [cp] lib/pyre/viz/filters/Parametric.icc
#   [cp] lib/pyre/viz/filters/Phase.icc
#   [cp] lib/pyre/viz/filters/PolarSaw.icc
#   [cp] lib/pyre/viz/filters/Power.icc
#   [cp] lib/pyre/viz/filters/Real.icc
#   [cp] lib/pyre/viz/filters/Uniform.icc
#   [cp] lib/pyre/viz/colorspaces/hl.h
#   [cp] lib/pyre/viz/colorspaces/hsb.h
#   [cp] lib/pyre/viz/colorspaces/hsl.h
#   [cp] lib/pyre/geometry/Brick.h
#   [cp] lib/pyre/geometry/PointCloud.h
#   [cp] lib/pyre/geometry/Point.h
#   [cp] lib/pyre/geometry/public.h
#   [cp] lib/pyre/geometry/Brick.icc
#   [cp] lib/pyre/geometry/PointCloud.icc
#   [cp] lib/pyre/geometry/Point.icc
#   [cp] lib/pyre/memory/api.h
#   [cp] lib/pyre/memory/Cell.h
#   [cp] lib/pyre/memory/externals.h
#   [cp] lib/pyre/memory/FileMap.h
#   [cp] lib/pyre/memory/forward.h
#   [cp] lib/pyre/memory/Heap.h
#   [cp] lib/pyre/memory/Map.h
#   [cp] lib/pyre/memory/public.h
#   [cp] lib/pyre/memory/Stack.h
#   [cp] lib/pyre/memory/View.h
#   [cp] lib/pyre/memory/Cell.icc
#   [cp] lib/pyre/memory/FileMap.icc
#   [cp] lib/pyre/memory/Heap.icc
#   [cp] lib/pyre/memory/Map.icc
#   [cp] lib/pyre/memory/Stack.icc
#   [cp] lib/pyre/memory/View.icc
#   [cp] lib/pyre/h5/api.h
#   [cp] lib/pyre/h5/datasets.h
#   [cp] lib/pyre/h5/datatypes.h
#   [cp] lib/pyre/h5/external.h
#   [cp] lib/pyre/h5/forward.h
#   [cp] lib/pyre/h5/public.h
#   [cp] lib/pyre/timers/api.h
#   [cp] lib/pyre/timers/externals.h
#   [cp] lib/pyre/timers/forward.h
#   [cp] lib/pyre/timers/Movement.h
#   [cp] lib/pyre/timers/ProcessClock.h
#   [cp] lib/pyre/timers/Proxy.h
#   [cp] lib/pyre/timers/public.h
#   [cp] lib/pyre/timers/Registrar.h
#   [cp] lib/pyre/timers/Timer.h
#   [cp] lib/pyre/timers/WallClock.h
#   [cp] lib/pyre/timers/Movement.icc
#   [cp] lib/pyre/timers/ProcessClock.icc
#   [cp] lib/pyre/timers/Proxy.icc
#   [cp] lib/pyre/timers/Registrar.icc
#   [cp] lib/pyre/timers/Timer.icc
#   [cp] lib/pyre/timers/WallClock.icc
#   [cp] lib/pyre/grid/api.h
#   [cp] lib/pyre/grid/Canonical.h
#   [cp] lib/pyre/grid/externals.h
#   [cp] lib/pyre/grid/forward.h
#   [cp] lib/pyre/grid/Grid.h
#   [cp] lib/pyre/grid/GridIterator.h
#   [cp] lib/pyre/grid/Index.h
#   [cp] lib/pyre/grid/IndexIterator.h
#   [cp] lib/pyre/grid/Order.h
#   [cp] lib/pyre/grid/OrderIterator.h
#   [cp] lib/pyre/grid/Product.h
#   [cp] lib/pyre/grid/public.h
#   [cp] lib/pyre/grid/Rep.h
#   [cp] lib/pyre/grid/Shape.h
#   [cp] lib/pyre/grid/Canonical.icc
#   [cp] lib/pyre/grid/Grid.icc
#   [cp] lib/pyre/grid/GridIterator.icc
#   [cp] lib/pyre/grid/Index.icc
#   [cp] lib/pyre/grid/IndexIterator.icc
#   [cp] lib/pyre/grid/Order.icc
#   [cp] lib/pyre/grid/OrderIterator.icc
#   [cp] lib/pyre/grid/Product.icc
#   [cp] lib/pyre/grid/Rep.icc
#   [cp] lib/pyre/grid/Shape.icc
#   [cp] lib/pyre/algebra/BCD.h
#   [cp] lib/pyre/algebra/operators.h
#   [cp] lib/pyre/algebra/BCD.icc
#   [cp] lib/pyre/algebra/operators.icc
#   [cp] lib/pyre/patterns/Registrar.h
#   [cp] lib/pyre/patterns/Registrar.icc
#   [c++] lib/pyre/memory/FileMap.cc
#   [ar] libpyre.a
#   [dll] libpyre.so
#   [lib] pyre.lib
#   [mkdir] /tmp/builds/opt-shared-linux-x86_64/pyre-gsl/libgslmodule/
#   [c++] extensions/gsl/blas.cc
#   [c++] extensions/gsl/exceptions.cc
#   [c++] extensions/gsl/histogram.cc
#   [c++] extensions/gsl/linalg.cc
#   [c++] extensions/gsl/matrix.cc
#   [c++] extensions/gsl/metadata.cc
#   [c++] extensions/gsl/numpy.cc
#   [c++] extensions/gsl/pdf.cc
#   [c++] extensions/gsl/permutation.cc
#   [c++] extensions/gsl/rng.cc
#   [c++] extensions/gsl/stats.cc
#   [c++] extensions/gsl/vector.cc
#   [ar] libgslmodule.a
#   [lib] pyre-gsl.ext.lib
#   [mkdir] /home/jovyan/.local/envs/qed/include/pyre/gsl/
#   [cp] extensions/gsl/capsules.h
#   [module] extensions/gsl/gsl.cc
#   [ext] pyre-gsl.ext
#   [project] pyre-gsl
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/components/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/calc/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/algebraic/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/shells/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/externals/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/weaver/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/flow/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/http/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/geometry/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/filesystem/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/db/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/tabular/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/traits/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/primitives/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/extensions/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/parsing/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/records/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/platforms/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/framework/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/h5/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/h5/typed/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/timers/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/smith/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/xml/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/grid/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/nexus/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/descriptors/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/ipc/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/schemata/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/tracking/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/handbook/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/handbook/elements/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/config/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/config/cfg/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/config/pfg/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/config/native/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/config/pml/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/config/odb/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/config/yaml/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/patterns/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/constraints/
#   [mkdir] /home/jovyan/.local/envs/qed/lib/python3.9/site-packages/pyre/units/
#   [mkdir] /home/jovyan/.local/envs/qed/share/pyre/
#   [python] packages/pyre/__init__.py
#   [python] packages/pyre/services.py
#   [python] packages/pyre/components/Actor.py
#   [python] packages/pyre/components/CompatibilityReport.py
#   [python] packages/pyre/components/Component.py
#   [python] packages/pyre/components/Configurable.py
#   [python] packages/pyre/components/exceptions.py
#   [python] packages/pyre/components/Foundry.py
#   [python] packages/pyre/components/__init__.py
#   [python] packages/pyre/components/Inventory.py
#   [python] packages/pyre/components/Monitor.py
#   [python] packages/pyre/components/PrivateInventory.py
#   [python] packages/pyre/components/Protocol.py
#   [python] packages/pyre/components/PublicInventory.py
#   [python] packages/pyre/components/Registrar.py
#   [python] packages/pyre/components/Requirement.py
#   [python] packages/pyre/components/Revision.py
#   [python] packages/pyre/components/Role.py
#   [python] packages/pyre/components/Tracker.py
#   [python] packages/pyre/calc/Average.py
#   [python] packages/pyre/calc/Calculator.py
#   [python] packages/pyre/calc/Composite.py
#   [python] packages/pyre/calc/Const.py
#   [python] packages/pyre/calc/Count.py
#   [python] packages/pyre/calc/Datum.py
#   [python] packages/pyre/calc/Dependency.py
#   [python] packages/pyre/calc/Dependent.py
#   [python] packages/pyre/calc/Evaluator.py
#   [python] packages/pyre/calc/exceptions.py
#   [python] packages/pyre/calc/Expression.py
#   [python] packages/pyre/calc/Filter.py
#   [python] packages/pyre/calc/Hierarchical.py
#   [python] packages/pyre/calc/__init__.py
#   [python] packages/pyre/calc/Interpolation.py
#   [python] packages/pyre/calc/Mapping.py
#   [python] packages/pyre/calc/Maximum.py
#   [python] packages/pyre/calc/Memo.py
#   [python] packages/pyre/calc/Minimum.py
#   [python] packages/pyre/calc/NodeInfo.py
#   [python] packages/pyre/calc/Node.py
#   [python] packages/pyre/calc/Observable.py
#   [python] packages/pyre/calc/Observer.py
#   [python] packages/pyre/calc/Postprocessor.py
#   [python] packages/pyre/calc/Preprocessor.py
#   [python] packages/pyre/calc/Probe.py
#   [python] packages/pyre/calc/Product.py
#   [python] packages/pyre/calc/Reactor.py
#   [python] packages/pyre/calc/Reference.py
#   [python] packages/pyre/calc/Sequence.py
#   [python] packages/pyre/calc/Sum.py
#   [python] packages/pyre/calc/SymbolTable.py
#   [python] packages/pyre/calc/Unresolved.py
#   [python] packages/pyre/calc/Value.py
#   [python] packages/pyre/algebraic/AbstractNode.py
#   [python] packages/pyre/algebraic/Algebra.py
#   [python] packages/pyre/algebraic/Arithmetic.py
#   [python] packages/pyre/algebraic/Boolean.py
#   [python] packages/pyre/algebraic/Composite.py
#   [python] packages/pyre/algebraic/exceptions.py
#   [python] packages/pyre/algebraic/__init__.py
#   [python] packages/pyre/algebraic/Leaf.py
#   [python] packages/pyre/algebraic/Literal.py
#   [python] packages/pyre/algebraic/Operator.py
#   [python] packages/pyre/algebraic/Ordering.py
#   [python] packages/pyre/algebraic/Variable.py
#   [python] packages/pyre/shells/Action.py
#   [python] packages/pyre/shells/ANSI.py
#   [python] packages/pyre/shells/Application.py
#   [python] packages/pyre/shells/ASCII.py
#   [python] packages/pyre/shells/Command.py
#   [python] packages/pyre/shells/CSI.py
#   [python] packages/pyre/shells/Daemon.py
#   [python] packages/pyre/shells/Director.py
#   [python] packages/pyre/shells/Executive.py
#   [python] packages/pyre/shells/Fork.py
#   [python] packages/pyre/shells/__init__.py
#   [python] packages/pyre/shells/Interactive.py
#   [python] packages/pyre/shells/IPython.py
#   [python] packages/pyre/shells/Layout.py
#   [python] packages/pyre/shells/Panel.py
#   [python] packages/pyre/shells/Plain.py
#   [python] packages/pyre/shells/Plexus.py
#   [python] packages/pyre/shells/Repertoire.py
#   [python] packages/pyre/shells/Script.py
#   [python] packages/pyre/shells/Shell.py
#   [python] packages/pyre/shells/Terminal.py
#   [python] packages/pyre/shells/User.py
#   [python] packages/pyre/shells/Web.py
#   [python] packages/pyre/externals/BLAS.py
#   [python] packages/pyre/externals/Cython.py
#   [python] packages/pyre/externals/GCC.py
#   [python] packages/pyre/externals/GSL.py
#   [python] packages/pyre/externals/HDF5.py
#   [python] packages/pyre/externals/__init__.py
#   [python] packages/pyre/externals/Installation.py
#   [python] packages/pyre/externals/LibraryInstallation.py
#   [python] packages/pyre/externals/Library.py
#   [python] packages/pyre/externals/Metis.py
#   [python] packages/pyre/externals/MPI.py
#   [python] packages/pyre/externals/Package.py
#   [python] packages/pyre/externals/ParMetis.py
#   [python] packages/pyre/externals/PETSc.py
#   [python] packages/pyre/externals/Postgres.py
#   [python] packages/pyre/externals/Python.py
#   [python] packages/pyre/externals/ToolInstallation.py
#   [python] packages/pyre/externals/Tool.py
#   [python] packages/pyre/externals/VTK.py
#   [python] packages/pyre/weaver/Banner.py
#   [python] packages/pyre/weaver/BlockComments.py
#   [python] packages/pyre/weaver/BlockMill.py
#   [python] packages/pyre/weaver/Cfg.py
#   [python] packages/pyre/weaver/C.py
#   [python] packages/pyre/weaver/CSh.py
#   [python] packages/pyre/weaver/Cxx.py
#   [python] packages/pyre/weaver/Expression.py
#   [python] packages/pyre/weaver/F77.py
#   [python] packages/pyre/weaver/F90.py
#   [python] packages/pyre/weaver/HTML.py
#   [python] packages/pyre/weaver/HTTP.py
#   [python] packages/pyre/weaver/Indenter.py
#   [python] packages/pyre/weaver/__init__.py
#   [python] packages/pyre/weaver/Language.py
#   [python] packages/pyre/weaver/LineComments.py
#   [python] packages/pyre/weaver/LineMill.py
#   [python] packages/pyre/weaver/Make.py
#   [python] packages/pyre/weaver/Mill.py
#   [python] packages/pyre/weaver/MixedComments.py
#   [python] packages/pyre/weaver/Perl.py
#   [python] packages/pyre/weaver/PFG.py
#   [python] packages/pyre/weaver/Python.py
#   [python] packages/pyre/weaver/Sh.py
#   [python] packages/pyre/weaver/SQL.py
#   [python] packages/pyre/weaver/Stationery.py
#   [python] packages/pyre/weaver/SVG.py
#   [python] packages/pyre/weaver/TeX.py
#   [python] packages/pyre/weaver/Weaver.py
#   [python] packages/pyre/weaver/XML.py
#   [python] packages/pyre/flow/Binder.py
#   [python] packages/pyre/flow/DynamicWorkflow.py
#   [python] packages/pyre/flow/exceptions.py
#   [python] packages/pyre/flow/FactoryMaker.py
#   [python] packages/pyre/flow/Factory.py
#   [python] packages/pyre/flow/FactoryStatus.py
#   [python] packages/pyre/flow/FlowMaster.py
#   [python] packages/pyre/flow/Flow.py
#   [python] packages/pyre/flow/__init__.py
#   [python] packages/pyre/flow/NameGenerator.py
#   [python] packages/pyre/flow/Node.py
#   [python] packages/pyre/flow/Producer.py
#   [python] packages/pyre/flow/Product.py
#   [python] packages/pyre/flow/ProductStatus.py
#   [python] packages/pyre/flow/Specification.py
#   [python] packages/pyre/flow/Status.py
#   [python] packages/pyre/flow/Workflow.py
#   [python] packages/pyre/http/documents.py
#   [python] packages/pyre/http/exceptions.py
#   [python] packages/pyre/http/__init__.py
#   [python] packages/pyre/http/Request.py
#   [python] packages/pyre/http/Response.py
#   [python] packages/pyre/http/responses.py
#   [python] packages/pyre/http/Server.py
#   [python] packages/pyre/geometry/CPGrid.py
#   [python] packages/pyre/geometry/Field.py
#   [python] packages/pyre/geometry/Grid.py
#   [python] packages/pyre/geometry/__init__.py
#   [python] packages/pyre/geometry/Mesh.py
#   [python] packages/pyre/geometry/Octree.py
#   [python] packages/pyre/geometry/PointCloud.py
#   [python] packages/pyre/geometry/Point.py
#   [python] packages/pyre/geometry/Simplex.py
#   [python] packages/pyre/geometry/SimplicialMesh.py
#   [python] packages/pyre/geometry/Surface.py
#   [python] packages/pyre/geometry/Triangulation.py
#   [python] packages/pyre/filesystem/BlockDevice.py
#   [python] packages/pyre/filesystem/CharacterDevice.py
#   [python] packages/pyre/filesystem/Directory.py
#   [python] packages/pyre/filesystem/exceptions.py
#   [python] packages/pyre/filesystem/Explorer.py
#   [python] packages/pyre/filesystem/File.py
#   [python] packages/pyre/filesystem/Filesystem.py
#   [python] packages/pyre/filesystem/Finder.py
#   [python] packages/pyre/filesystem/Folder.py
#   [python] packages/pyre/filesystem/HDF5.py
#   [python] packages/pyre/filesystem/InfoFile.py
#   [python] packages/pyre/filesystem/InfoFolder.py
#   [python] packages/pyre/filesystem/Info.py
#   [python] packages/pyre/filesystem/InfoStat.py
#   [python] packages/pyre/filesystem/InfoZipFile.py
#   [python] packages/pyre/filesystem/InfoZipFolder.py
#   [python] packages/pyre/filesystem/InfoZip.py
#   [python] packages/pyre/filesystem/__init__.py
#   [python] packages/pyre/filesystem/Link.py
#   [python] packages/pyre/filesystem/Local.py
#   [python] packages/pyre/filesystem/Naked.py
#   [python] packages/pyre/filesystem/NamedPipe.py
#   [python] packages/pyre/filesystem/Node.py
#   [python] packages/pyre/filesystem/Recognizer.py
#   [python] packages/pyre/filesystem/SimpleExplorer.py
#   [python] packages/pyre/filesystem/Socket.py
#   [python] packages/pyre/filesystem/Stat.py
#   [python] packages/pyre/filesystem/TreeExplorer.py
#   [python] packages/pyre/filesystem/Walker.py
#   [python] packages/pyre/filesystem/Zip.py
#   [python] packages/pyre/db/actions.py
#   [python] packages/pyre/db/Backup.py
#   [python] packages/pyre/db/Client.py
#   [python] packages/pyre/db/Collation.py
#   [python] packages/pyre/db/DataStore.py
#   [python] packages/pyre/db/exceptions.py
#   [python] packages/pyre/db/expressions.py
#   [python] packages/pyre/db/FieldReference.py
#   [python] packages/pyre/db/FieldSelector.py
#   [python] packages/pyre/db/ForeignKey.py
#   [python] packages/pyre/db/__init__.py
#   [python] packages/pyre/db/literals.py
#   [python] packages/pyre/db/Measure.py
#   [python] packages/pyre/db/Object.py
#   [python] packages/pyre/db/Persistent.py
#   [python] packages/pyre/db/Postgres.py
#   [python] packages/pyre/db/Query.py
#   [python] packages/pyre/db/Reference.py
#   [python] packages/pyre/db/Schemer.py
#   [python] packages/pyre/db/Selector.py
#   [python] packages/pyre/db/Server.py
#   [python] packages/pyre/db/SQLite.py
#   [python] packages/pyre/db/SQL.py
#   [python] packages/pyre/db/Table.py
#   [python] packages/pyre/tabular/Chart.py
#   [python] packages/pyre/tabular/Column.py
#   [python] packages/pyre/tabular/Dimension.py
# ...
# asset node_modules_graphiql_react_dist_closebrackets_es_js.js 23.5 KiB [emitted]
# asset node_modules_graphiql_react_dist_mode_es_js.js 22.3 KiB [emitted]
# asset node_modules_graphiql_react_dist_hint_es2_js.js 20.7 KiB [emitted]
# asset node_modules_graphiql_react_dist_matchbrackets_es_js.js 19.8 KiB [emitted]
# asset node_modules_graphiql_react_dist_dialog_es_js.js 16.9 KiB [emitted]
# asset node_modules_graphiql_react_dist_brace-fold_es_js.js 16.7 KiB [emitted]
# asset node_modules_graphiql_react_dist_info-addon_es_js.js 14.8 KiB [emitted]
# asset qed.html 2.3 KiB [emitted]
# runtime modules 7.05 KiB 11 modules
# orphan modules 10.8 KiB [orphan] 6 modules
# modules by path ./node_modules/ 4.05 MiB 495 modules
# modules by path ./client/ 610 KiB
#   modules by path ./client/views/ 295 KiB 136 modules
#   modules by path ./client/widgets/ 188 KiB 72 modules
#   modules by path ./client/shapes/ 74 KiB 38 modules
#   modules by path ./client/activities/ 20.4 KiB 20 modules
#   modules by path ./client/context/ 21.5 KiB 7 modules
#   modules by path ./client/hooks/*.js 7.14 KiB
#     ./client/hooks/index.js 313 bytes [built] [code generated]
#     + 2 modules
#   modules by path ./client/*.js 4.65 KiB
#     ./client/qed.js 3.22 KiB [built] [code generated]
#     ./client/palette.js 1.43 KiB [built] [code generated]
# webpack 5.73.0 compiled successfully in 5665 ms
#   [cp] build/qed.html
#   [cp] build/qed.js
#   [webpack] qed.ux
#   [project] qed
#
# ~/scratch_workspace
# Installed kernelspec qed in /home/jovyan/.local/share/jupyter/kernels/qed
# ERROR conda.cli.main_run:execute(41): `conda run kernda --env-dir /home/jovyan/.local/envs/qed --display-name qed -o /home/jovyan/.local/share/jupyter/kernels/qed/kernel.json` failed. (See above for error)
# /tmp/tmpfaic6wpj: line 3: kernda: command not found
# Loaded plugins: fastestmirror, ovl
# Loading mirror speeds from cached hostfile
#  * base: download.cf.centos.org
#  * centos-sclo-rh: download.cf.centos.org
#  * extras: download.cf.centos.org
#  * updates: download.cf.centos.org
# Resolving Dependencies
# --> Running transaction check
# ---> Package httpd.x86_64 0:2.4.6-97.el7.centos.5 will be installed
# --> Processing Dependency: httpd-tools = 2.4.6-97.el7.centos.5 for package: httpd-2.4.6-97.el7.centos.5.x86_64
# --> Processing Dependency: system-logos >= 7.92.1-1 for package: httpd-2.4.6-97.el7.centos.5.x86_64
# --> Processing Dependency: /etc/mime.types for package: httpd-2.4.6-97.el7.centos.5.x86_64
# --> Processing Dependency: libaprutil-1.so.0()(64bit) for package: httpd-2.4.6-97.el7.centos.5.x86_64
# --> Processing Dependency: libapr-1.so.0()(64bit) for package: httpd-2.4.6-97.el7.centos.5.x86_64
# --> Running transaction check
# ---> Package apr.x86_64 0:1.4.8-7.el7 will be installed
# ---> Package apr-util.x86_64 0:1.5.2-6.el7 will be installed
# ---> Package centos-logos.noarch 0:70.0.6-3.el7.centos will be installed
# ---> Package httpd-tools.x86_64 0:2.4.6-97.el7.centos.5 will be installed
# ---> Package mailcap.noarch 0:2.1.41-2.el7 will be installed
# --> Finished Dependency Resolution
#
# Dependencies Resolved
#
# ================================================================================
#  Package           Arch        Version                       Repository    Size
# ================================================================================
# Installing:
#  httpd             x86_64      2.4.6-97.el7.centos.5         updates      2.7 M
# Installing for dependencies:
#  apr               x86_64      1.4.8-7.el7                   base         104 k
#  apr-util          x86_64      1.5.2-6.el7                   base          92 k
#  centos-logos      noarch      70.0.6-3.el7.centos           base          21 M
#  httpd-tools       x86_64      2.4.6-97.el7.centos.5         updates       94 k
#  mailcap           noarch      2.1.41-2.el7                  base          31 k
#
# Transaction Summary
# ================================================================================
# Install  1 Package (+5 Dependent packages)
#
# Total download size: 24 M
# Installed size: 32 M
# Downloading packages:
# --------------------------------------------------------------------------------
# Total                                               33 MB/s |  24 MB  00:00
# Running transaction check
# Running transaction test
# Transaction test succeeded
# Running transaction
#   Installing : apr-1.4.8-7.el7.x86_64                                       1/6
#   Installing : apr-util-1.5.2-6.el7.x86_64                                  2/6
#   Installing : httpd-tools-2.4.6-97.el7.centos.5.x86_64                     3/6
#   Installing : centos-logos-70.0.6-3.el7.centos.noarch                      4/6
#   Installing : mailcap-2.1.41-2.el7.noarch                                  5/6
#   Installing : httpd-2.4.6-97.el7.centos.5.x86_64                           6/6
#   Verifying  : httpd-tools-2.4.6-97.el7.centos.5.x86_64                     1/6
#   Verifying  : mailcap-2.1.41-2.el7.noarch                                  2/6
#   Verifying  : apr-1.4.8-7.el7.x86_64                                       3/6
#   Verifying  : apr-util-1.5.2-6.el7.x86_64                                  4/6
#   Verifying  : httpd-2.4.6-97.el7.centos.5.x86_64                           5/6
#   Verifying  : centos-logos-70.0.6-3.el7.centos.noarch                      6/6
#
# Installed:
#   httpd.x86_64 0:2.4.6-97.el7.centos.5
#
# Dependency Installed:
#   apr.x86_64 0:1.4.8-7.el7
#   apr-util.x86_64 0:1.5.2-6.el7
#   centos-logos.noarch 0:70.0.6-3.el7.centos
#   httpd-tools.x86_64 0:2.4.6-97.el7.centos.5
#   mailcap.noarch 0:2.1.41-2.el7
#
# Complete!
# Collecting flask
#   Using cached Flask-2.1.2-py3-none-any.whl (95 kB)
# Requirement already satisfied: Jinja2>=3.0 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from flask) (3.1.1)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from flask) (4.11.3)
# Collecting click>=8.0
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Collecting itsdangerous>=2.0
#   Using cached itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting Werkzeug>=2.0
#   Using cached Werkzeug-2.1.2-py3-none-any.whl (224 kB)
# Requirement already satisfied: zipp>=0.5 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from importlib-metadata>=3.6.0->flask) (3.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from Jinja2>=3.0->flask) (2.1.1)
# Installing collected packages: Werkzeug, itsdangerous, click, flask
# Successfully installed Werkzeug-2.1.2 click-8.1.3 flask-2.1.2 itsdangerous-2.1.2
# Collecting jupyter-server-proxy
#   Using cached jupyter_server_proxy-3.2.1-py3-none-any.whl (35 kB)
# Collecting simpervisor>=0.4
#   Using cached simpervisor-0.4-py3-none-any.whl (5.7 kB)
# Requirement already satisfied: jupyter-server>=1.0 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from jupyter-server-proxy) (1.16.0)
# Collecting aiohttp
#   Using cached aiohttp-3.8.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.2 MB)
# Requirement already satisfied: traitlets>=5.1.0 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from jupyter-server>=1.0->jupyter-server-proxy) (5.1.1)
# Requirement already satisfied: Send2Trash in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from jupyter-server>=1.0->jupyter-server-proxy) (1.8.0)
# Requirement already satisfied: pyzmq>=17 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from jupyter-server>=1.0->jupyter-server-proxy) (22.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from jupyter-server>=1.0->jupyter-server-proxy) (0.13.3)
# Requirement already satisfied: tornado>=6.1.0 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from jupyter-server>=1.0->jupyter-server-proxy) (6.1)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from jupyter-server>=1.0->jupyter-server-proxy) (6.5.0)
# Requirement already satisfied: prometheus-client in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from jupyter-server>=1.0->jupyter-server-proxy) (0.14.1)
# Requirement already satisfied: websocket-client in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from jupyter-server>=1.0->jupyter-server-proxy) (1.3.2)
# Requirement already satisfied: anyio>=3.1.0 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from jupyter-server>=1.0->jupyter-server-proxy) (3.5.0)
# Requirement already satisfied: packaging in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from jupyter-server>=1.0->jupyter-server-proxy) (21.3)
# Requirement already satisfied: nbformat>=5.2.0 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from jupyter-server>=1.0->jupyter-server-proxy) (5.3.0)
# Requirement already satisfied: jinja2 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from jupyter-server>=1.0->jupyter-server-proxy) (3.1.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from jupyter-server>=1.0->jupyter-server-proxy) (7.2.2)
# Requirement already satisfied: jupyter-core>=4.7.0 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from jupyter-server>=1.0->jupyter-server-proxy) (4.9.2)
# Requirement already satisfied: argon2-cffi in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from jupyter-server>=1.0->jupyter-server-proxy) (21.3.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Using cached yarl-1.7.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (304 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from aiohttp->jupyter-server-proxy) (2.0.12)
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting frozenlist>=1.1.1
#   Using cached frozenlist-1.3.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (156 kB)
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-6.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
# Requirement already satisfied: attrs>=17.3.0 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from aiohttp->jupyter-server-proxy) (21.4.0)
# Requirement already satisfied: sniffio>=1.1 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server>=1.0->jupyter-server-proxy) (1.2.0)
# Requirement already satisfied: idna>=2.8 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server>=1.0->jupyter-server-proxy) (3.3)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from jupyter-client>=6.1.12->jupyter-server>=1.0->jupyter-server-proxy) (1.5.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from jupyter-client>=6.1.12->jupyter-server>=1.0->jupyter-server-proxy) (2.8.2)
# Requirement already satisfied: entrypoints in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from jupyter-client>=6.1.12->jupyter-server>=1.0->jupyter-server-proxy) (0.4)
# Requirement already satisfied: tinycss2 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy) (1.1.1)
# Requirement already satisfied: jupyterlab-pygments in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy) (0.2.1)
# Requirement already satisfied: defusedxml in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy) (0.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy) (2.1.1)
# Requirement already satisfied: bleach in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy) (5.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy) (4.11.1)
# Requirement already satisfied: pygments>=2.4.1 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy) (2.11.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy) (0.6.0)
# Requirement already satisfied: fastjsonschema in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from nbformat>=5.2.0->jupyter-server>=1.0->jupyter-server-proxy) (2.15.3)
# Requirement already satisfied: jsonschema>=2.6 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from nbformat>=5.2.0->jupyter-server>=1.0->jupyter-server-proxy) (4.4.0)
# Requirement already satisfied: ptyprocess in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from terminado>=0.8.3->jupyter-server>=1.0->jupyter-server-proxy) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from argon2-cffi->jupyter-server>=1.0->jupyter-server-proxy) (21.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from packaging->jupyter-server>=1.0->jupyter-server-proxy) (3.0.8)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.2.0->jupyter-server>=1.0->jupyter-server-proxy) (0.18.1)
# Requirement already satisfied: six>=1.5 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->jupyter-server>=1.0->jupyter-server-proxy) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server>=1.0->jupyter-server-proxy) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy) (2.3.1)
# Requirement already satisfied: webencodings in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from bleach->nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy) (0.5.1)
# Requirement already satisfied: pycparser in /home/jovyan/.local/envs/qed/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server>=1.0->jupyter-server-proxy) (2.21)
# Installing collected packages: simpervisor, multidict, frozenlist, async-timeout, yarl, aiosignal, aiohttp, jupyter-server-proxy
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 frozenlist-1.3.0 jupyter-server-proxy-3.2.1 multidict-6.0.2 simpervisor-0.4 yarl-1.7.2
# Enabling: jupyter_server_proxy
# - Writing config: /home/jovyan/.jupyter
#     - Validating...
#       jupyter_server_proxy  OK
# Building jupyterlab assets (production, minimized)
